# %% [markdown]
# Programa para obtener una PDF dados los valores CDF y una distribución normal

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats  as stats
import random
% matplotlib inline

# %%
mu, sigma = 70, 2 # mean and standard deviation

# %%
# Definiendo funciones 

#PDF (probability distribution function) y CDF (cumulative distribution function)

def f_cdf(x,mu,sigma):
    return stats.norm.cdf(x,loc = mu, scale= sigma)    

def f_pdf(x,mu,sigma):
    return stats.norm.pdf(x,loc = mu, scale = sigma)

# Funcion gaussiana
def gauss(mu,sigma,bins):
    return 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) )

# %%
# Generando valores aleatorios para cdf
cdf_ran = np.random.random(1000)

# Obteniendo valores x dada una probabilidad acumulada para el promedio y desviación estandar de la distribucion.
x=stats.norm.ppf(cdf_ran, mu, sigma) 

# Graficando CDF
plt.plot(x,cdf_ran,'.',label='CDF aleatoria')
plt.xlabel('x')
plt.ylabel('CDF')
plt.title('Densidad de probabilidad acumulada')
plt.legend()

# %%
# Graficando histograma para obtener PDF
count, bins, ignored = plt.hist(x, len(x), normed=True)

# Curva gaussiana para el histograma
plt.plot(bins, gauss(mu,sigma,bins),linewidth=2, color='r',label='PDF aleatoria')
plt.xlabel('x')
plt.ylabel('PDF')
plt.title('Densidad de probabilidad')
plt.legend()

# %%
# PDF obtenida usando el comando de python
pdf_py = f_pdf(x,mu,sigma)

# Grafica para comparar PDF de python y la obtenida con valores aleatorios de CDF
plt.plot(x,pdf_py,'x',color='gray',label='PDF python')
plt.plot(bins, gauss(mu,sigma,bins),linewidth=2, color='r',label='PDF aleatoria')
plt.xlabel('x')
plt.ylabel('PDF')
plt.title('Densidad de probabilidad aleatoria y python')
plt.legend()

# %% [markdown]
# NOTA : USANDO MEAN=70 Y SIGMA=1 SE OBTIENEN LAS GRAFICAS DE LA PRESENTACION EN CLASE

# %%
mu,sigma=70,1
# Generando valores aleatorios para cdf
cdf_ran = np.random.random(1000)

# Obteniendo valores x dada una probabilidad acumulada para el promedio y desviación estandar de la distribucion.
x=stats.norm.ppf(cdf_ran, mu, sigma) 

# Graficando CDF
plt.plot(x,cdf_ran,'.',label='CDF aleatoria')
plt.xlabel('x')
plt.ylabel('probabilidad')
plt.title('Densidad de probabilidad')
plt.legend()

# Graficando histograma para obtener PDF
count, bins, ignored = plt.hist(x, len(x), normed=True)

# Curva gaussiana para el histograma
plt.plot(bins, gauss(mu,sigma,bins),linewidth=2, color='r',label='PDF aleatoria')

# PDF obtenida usando el comando de python
pdf_py = f_pdf(x,mu,sigma)

# Grafica para comparar PDF de python y la obtenida con valores aleatorios de CDF
plt.plot(x,pdf_py,'x',color='gray',label='PDF python')
plt.legend()
